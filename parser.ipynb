# %%
import pandas as pd
import numpy as np
import datetime as dt
import time

# %%
df = pd.read_json("Data.json")
df = df.transpose()
df.columns = ["device", "location", "event", "guest"]
names = []
for val in df['guest'].unique():
    names.append(val)
timeFrame = {df.first_valid_index(), df.last_valid_index()}

# %%
class Person:
    def __init__(self, name, df):
        self.name = name
        self.events = pd.DataFrame({"device": [], "location": [], "event": [], "guest": []})
        for row in df.itertuples(index=True):
            if (getattr(row,"guest") == self.name):
                self.events.loc[getattr(row,"Index")] = [getattr(row,"device"),getattr(row,"location"),getattr(row,"event"),getattr(row,"guest")]

# %%
people = []
for i in names:
    people.append(Person(i, df))

# %%
names
# Out:
# ['Veronica',
#  'Jason',
#  'Thomas',
#  'Eugene',
#  'Salina',
#  'Rob',
#  'Kristina',
#  'Alok',
#  'Marc-Andre',
#  'n/a',
#  'Dave',
#  'James',
#  'Harrison']

# %%
people[8].events
# Out:
#                            device location                      event  \
# 2020-01-04 16:33:11  access point    ap1-4                 new client
# 2020-01-04 16:33:30  access point    ap1-2             user connected
# 2020-01-04 16:33:39   door sensor      156  successful keycard unlock
# 2020-01-04 16:33:42   door sensor     156b  successful keycard unlock
# 2020-01-04 16:34:01   door sensor     156b        unlocked no keycard
# 2020-01-04 16:34:04   door sensor      156        unlocked no keycard
# 2020-01-04 16:34:12  access point    ap1-4             user connected
# 2020-01-04 16:35:02  access point    ap2-1             user connected
# 2020-01-04 16:35:11   door sensor      233  successful keycard unlock
# 2020-01-04 16:35:15   door sensor      233                door closed
# 2020-01-04 17:00:07   door sensor      233        unlocked no keycard
# 2020-01-04 17:00:09   door sensor      233                door closed
# 2020-01-04 17:00:19   door sensor      231  successful keycard unlock
# 2020-01-04 17:00:22   door sensor      231                door closed
# 2020-01-04 17:15:17   door sensor      231        unlocked no keycard
# 2020-01-04 17:15:20   door sensor      231                door closed
# 2020-01-04 17:15:31   door sensor      210        unlocked no keycard
# 2020-01-04 17:16:02   door sensor      210                door closed
# 2020-01-04 17:16:21   door sensor      232  successful keycard unlock
# 2020-01-04 17:16:27   door sensor      232                door closed
# 2020-01-04 17:45:17   door sensor      232        unlocked no keycard
# 2020-01-04 17:45:22   door sensor      232                door closed
# 2020-01-04 17:46:01   door sensor      210  successful keycard unlock
# 2020-01-04 17:46:05   door sensor      210                door closed
# 2020-01-04 18:36:11   door sensor      210        unlocked no keycard
# 2020-01-04 18:36:14   door sensor      210                door closed
# 2020-01-04 18:36:25  access point    ap2-3             user connected
# 2020-01-04 18:36:45  access point    ap2-2             user connected
# 2020-01-04 18:37:04   door sensor      244  successful keycard unlock
# 2020-01-04 18:37:06   door sensor      244                door closed
# ...                           ...      ...                        ...
# 2020-01-04 21:54:07   door sensor     156b                door closed
# 2020-01-04 21:57:35   door sensor     156b        unlocked no keycard
# 2020-01-04 21:57:42   door sensor     156b                door closed
# 2020-01-04 21:57:45   door sensor      156        unlocked no keycard
# 2020-01-04 21:57:52   door sensor      156                door closed
# 2020-01-04 21:58:00  access point    ap1-4             user connected
# 2020-01-04 21:58:20  access point    ap1-4          user disconnected
# 2020-01-05 13:58:00  access point    ap1-4             user connected
# 2020-01-05 13:58:20  access point    ap1-2             user connected
# 2020-01-05 13:58:25   door sensor      156  successful keycard unlock
# 2020-01-05 14:08:14  Marc-Andre
# 2020-01-05 14:08:50  Marc-Andre
# 2020-01-05 14:08:53  Marc-Andre
# 2020-01-05 14:08:54  Marc-Andre
# 2020-01-05 14:08:56  Marc-Andre
# 2020-01-05 14:35:00  Marc-Andre
# 2020-01-05 14:35:07  Marc-Andre
# 2020-01-05 14:35:12  Marc-Andre
# 2020-01-05 14:35:19  Marc-Andre
# 2020-01-05 15:00:00  Marc-Andre
# 2020-01-05 15:00:07  Marc-Andre
# 2020-01-05 15:00:12  Marc-Andre
# 2020-01-05 15:00:19  Marc-Andre
#
# [89 rows x 4 columns]

# %%
people[0].events
# Out:
#                            device location                      event  \
# 2020-01-04 15:30:01  access point    ap1-1                 new client
# 2020-01-04 15:55:00   door sensor      110        unlocked no keycard
# 2020-01-04 15:55:02  access point    ap1-4             user connected
# 2020-01-04 15:55:07   door sensor      110                door closed
# 2020-01-04 15:55:22  access point    ap1-2             user connected
# 2020-01-04 16:01:00  access point    ap1-4             user connected
# 2020-01-04 16:01:20  access point    ap1-1             user connected
# 2020-01-04 16:01:30   door sensor      110  successful keycard unlock
# 2020-01-04 16:01:37   door sensor      110                door closed
# 2020-01-04 17:02:04   door sensor      110        unlocked no keycard
# 2020-01-04 17:02:24   door sensor      110                door closed
# 2020-01-04 17:02:28  access point    ap1-4             user connected
# 2020-01-04 17:02:31  access point    ap2-1             user connected
# 2020-01-04 17:02:45   door sensor      210  successful keycard unlock
# 2020-01-04 17:02:49   door sensor      210                door closed
# 2020-01-04 17:23:12   door sensor      210        unlocked no keycard
# 2020-01-04 17:23:15   door sensor      210                door closed
# 2020-01-04 17:23:17  access point    ap1-4             user connected
# 2020-01-04 17:23:21  access point    ap1-2             user connected
# 2020-01-04 17:23:27   door sensor      151  successful keycard unlock
# 2020-01-04 17:23:30   door sensor      151                door closed
# 2020-01-04 19:01:00   door sensor      151        unlocked no keycard
# 2020-01-04 19:01:07   door sensor      151                door closed
# 2020-01-04 19:01:17  access point    ap1-3             user connected
# 2020-01-04 19:39:50  access point    ap1-4             user connected
# 2020-01-04 19:40:00   door sensor      110  successful keycard unlock
# 2020-01-04 19:40:01  access point    ap1-1             user connected
# 2020-01-04 19:40:07   door sensor      110                door closed
# 2020-01-04 20:30:00   door sensor      110        unlocked no keycard
# 2020-01-04 20:30:02  access point    ap1-4             user connected
# ...                           ...      ...                        ...
# 2020-01-04 20:30:22  access point    ap1-2             user connected
# 2020-01-04 20:36:00  access point    ap1-4             user connected
# 2020-01-04 20:36:20  access point    ap1-1             user connected
# 2020-01-04 20:36:30   door sensor      110  successful keycard unlock
# 2020-01-04 20:36:37   door sensor      110                door closed
# 2020-01-04 22:30:00   door sensor      110        unlocked no keycard
# 2020-01-04 22:30:02  access point    ap1-4             user connected
# 2020-01-04 22:30:22   door sensor      110                door closed
# 2020-01-04 22:36:30  access point    ap1-2             user connected
# 2020-01-04 22:51:30  access point    ap1-3             user connected
# 2020-01-05 00:01:03  access point    ap2-1             user connected
# 2020-01-05 00:01:05   door sensor      210  successful keycard unlock
# 2020-01-05 00:02:10   door sensor      210                door closed
# 2020-01-05 00:30:01   door sensor      210        unlocked no keycard
# 2020-01-05 00:30:06   door sensor      210                door closed
